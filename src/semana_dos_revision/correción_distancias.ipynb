# %% [markdown]
# # Definición del Dataframe

# %%
import pandas as pd
df = pd.read_csv('/content/Tiempos_Logísticos_de_cada_viaje_de_vehículos_de_carga_20260615.csv')
# Out:
# /tmp/ipykernel_366/3437817860.py:2: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Tiempos_Logísticos_de_cada_viaje_de_vehículos_de_carga_20260615.csv')

# %% [markdown]
# ## Ver columnas del df

# %%
print(df.columns)
# Out:
# Index(['AÑO/MES', 'NATURALEZA', 'COD_PRODUCTO', 'PRODUCTO', 'CANTIDAD',
#        'UNID_MEDIDA', 'FECHASALIDACARGUE', 'HORA_SALIDA_CARGUE',
#        'FECHALLEGADADESCARGUE', 'HORA_LLEGADA_DESCARGUE', 'CODIGO_CARGUE',
#        'CARGUE', 'CODIGO_DESCARGUE', 'DESCARGUE', 'HORAS_VIAJE',
#        'HORAS_ESPERA_CARGUE', 'HORAS_CARGUE', 'HORAS_ESPERA_DESCARGUE',
#        'HORAS_DESCARGUE', 'VALOR_PACTADO', 'VALOR_PAGADO',
#        'CANTIDAD_REMESAS_VIAJE', 'EMPRESA_TRANSPORTE', 'PLACA',
#        'CONFIGURACION', 'CONDUCTOR'],
#       dtype='object')

# %% [markdown]
# ## ver los productos únicos

# %%
producto_unico =  pd.DataFrame(df['PRODUCTO'].unique(), columns=['PRODUCTO'])
producto_unico.to_csv('productos_unicos.csv', index = False)
#aquí hice un CSV para ver todos los productos unicos de forma más fácil

unidades_medida = df['UNID_MEDIDA'].unique()
print("las unidades de medida unicas que tengo: ")
print(unidades_medida)
# Out:
# las unidades de medida unicas que tengo:
# ['Kilogramos' nan 'Galones']

# %%
from google.colab import files
#Descargar la lista de productos unicos
files.download('productos_unicos.csv')

# %% [markdown]
# ## Ver palabras claves de la tabla PRODUCTO del df

# %%
import re

# 1. Definimos las palabras "basura" que no queremos que cuente como keywords (Stopwords)
palabras_ignoradas = [
    # --- ORIGINAL ---
    'de', 'y', 'en', 'la', 'el', 'los', 'las', 'con', 'para', 'por',
    'una', 'un', 'o', 'del', 'al', 'sin', 'que', 'su', 'a', 'productos',
    'varios', 'manufacturas', 'similares', 'preparaciones', 'demas', 'demás', 'sus',
    'otros', 'aparatos', 'materias', 'contenidos', 'miscelaneos', 'paqueteo', 'paquetes', 'incluso',
    'envases', 'inflamables', 'despojos', 'partes', 'estas', 'artículos', 'incluidos', 'articulos', 'diversos',

    # --- RONDAS 1 A 4 (Materiales, vehículos, empaques secos, polvos, etc.) ---
    'madera', 'papel', 'cementos', 'minerales', 'cartón', 'vehículos', 'industrias',
    'hierro', 'vegetal', 'cereales', 'cajas', 'acero', 'comestibles', 'carbón',
    'cajones', 'jaulas', 'carretes', 'pasta', 'celulosa', 'material', 'vidrio',
    'animales', 'plásticas', 'frescos', 'ciclos', 'fundición', 'piedras', 'malta',
    'fécula', 'almidón', 'sal', 'yesos', 'desperdicios', 'harina', 'carne', 'trigo',
    'refractarios', 'morteros', 'hormigones', 'carnes', 'orgánicos', 'inorgánicos',
    'tipo', 'azufre', 'tierras', 'tractores', 'cales', 'residuos', 'alimenticias',
    'partida', 'terrestres', 'automóviles', 'frutos', 'partidas', 'contenedores',
    'otras', 'carton', 'excepto', 'calderas', 'cerámicos', 'compuestos', 'maiz',
    'diversas', 'natural', 'inulina', 'alimentarias', 'alimentos', 'gluten',
    'maquinas', 'molinería', 'artefactos', 'mineral', 'máquinas', 'reactores',
    'nucleares', 'vehiculos', 'aseo', 'eléctrico', 'máquina', 'vegetales', 'base',
    'cuero', 'vacio', 'aves', 'origen', 'guarnicionería', 'talabartería', 'contenedor',
    'baules', 'maletines', 'carte', 'portadocumentos', 'maletas', 'ejemplo',
    'cafe', 'automoviles', 'naturales', 'incluidas', 'refrigerd', 'par', 'caucho',
    'plastico', 'cacao', 'ceramica', 'incluida', 'carbon', 'placas', 'expresados',
    'motores', 'aluminio', 'tapas', 'cemento', 'utilizadas', 'accesorios', 'hulla',
    'guata', 'confitería', 'azúcares', 'higienico', 'utilizado', 'azucar', 'sacos',
    'bolsas', 'toallitas', 'desmaquilla', 'expresadas', 'motor', 'uso', 'plantas',
    'comprendidas', 'alimentacion', 'copos', 'huevos', 'piedra', 'vivos', 'proyectados',
    'yeso', 'hidraulicos', 'domestico', 'pulverizar', 'solidos', 'clinker', 'aunqu',
    'usos', 'obtenidos', 'elementos', '1267', 'tostado', 'polvo', 'formas', 'cucuruchos',
    'principalmente', 'tocador', 'higiene', 'refrigerados', 'alear', 'coches', 'tubos',
    'superficie', 'agentes', 'jabon', 'turismo', 'pellets', 'tubula',

    # --- QUINTA RONDA (Nuevas palabras del archivo productos_unicos.csv) ---
    'sustancias', 'hilados', 'tejidos', 'fibras', 'textiles', 'cobre', 'punto',
    'instrumentos', 'sólidos', 'infecciosas', 'tóxicas', 'combustión', 'espontánea',
    'experimentar', 'artificiales', 'pueden', 'prendas', 'vestir', 'complementos',
    'semillas', 'hojas', 'hortalizas', 'desechos', 'metales', 'pelo', 'preparados',
    'discontinuas', 'derivados', 'cinc', 'tóxico', 'bruto', 'fotografía', 'electricos',
    'cinematografía', 'legumbres', 'óptica', 'extractos', 'sólido', 'plomo',
    'herramientas', 'objetos', 'mica', 'escorias', 'peletería', 'desdoblamiento'
]

# 2. Hacemos una copia de tu columna para no dañar los datos originales
# Lo pasamos a minúsculas para que "CRIBAS" y "cribas" cuenten como la misma palabra
textos_limpios = df['PRODUCTO'].astype(str).str.lower()

# 3. Quitamos signos de puntuación (cambiamos guiones, diagonales y paréntesis por espacios)
textos_limpios = textos_limpios.str.replace(r'[^\w\s]', ' ', regex=True)

# 4. Cortamos cada frase en palabras sueltas. Esto crea listas de palabras.
palabras_separadas = textos_limpios.str.split()

# 5. "Explotamos" la lista: Esto pone cada palabra en su propia fila para poder contarlas
todas_las_palabras = palabras_separadas.explode()

# 6. Limpieza final: Quitamos las palabras ignoradas y palabras de menos de 3 letras (ej. 'no', 'si')
keywords_reales = todas_las_palabras[~todas_las_palabras.isin(palabras_ignoradas)]
keywords_reales = keywords_reales[keywords_reales.str.len() > 2]

# 7. ¡A CONTAR! Sacamos el Top n de las palabras que más se repiten en tus productos
n = 60
top_keywords = keywords_reales.value_counts().head(n)

print("--- TOP KEYWORDS DE TUS PRODUCTOS ---")
print(top_keywords)
# si n es muy grande vamos a mejor converlo en un CSV
# Guardar directo definiendo el nombre del encabezado y del índice
top_keywords.to_csv('top_keywords.csv', index_label='Keyword')
# Out:
# --- TOP KEYWORDS DE TUS PRODUCTOS ---
# PRODUCTO
# líquidos          55543
# aceites           39878
# tambores          36815
# químicas          33710
# agua              26990
# bebidas           23976
# vinagre           23867
# alcohólicos       23561
# combustibles      23269
# leche             22584
# abonos            20924
# destilación       18095
# químicos          16163
# petróleo          14503
# aceite            13094
# quimicos          12925
# gasificada        11814
# grasas            11288
# combustible       10505
# cerveza            8661
# edulcorada         8608
# azucarada          8608
# damajuanas         8464
# botellas           8464
# bocales            8464
# bombonas           8464
# tarros             8464
# frascos            8464
# vías               8331
# férreas            8331
# semola             8260
# cascara            8122
# miel               7976
# ave                7961
# lácteos            7911
# yerba              7861
# mate               7861
# arroz              7853
# fundicion          7840
# papas              7795
# patatas            7795
# amianto            7750
# muebles            7694
# exclusion          7684
# morcajo            7616
# conjuntos          7610
# cama               7608
# isotopos           7589
# comprendidos       7578
# cortezas           7561
# moluscos           7521
# granulos           7423
# petroleo           7379
# lavar              7354
# jabones            7152
# primarias          7079
# otra               6900
# revestidos         6848
# refrigeradores     6815
# congeladores       6815
# Name: count, dtype: int64

# %% [markdown]
# ## Si fue muy grande el n de top_keywords o simplemente quieres el CSV, aquí está

# %%
files.download('top_keywords.csv')

# %% [markdown]
# ## Poner el código a correr y limpiar nuestro dataset

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

def calcular_haversine_vectorizado(lat1, lon1, lat2, lon2):
    R = 6371.0
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
    c = 2 * np.arcsin(np.sqrt(a))
    return R * c

def preprocesar_rndc_grupo1(ruta_archivo):
    print("=== INICIANDO PROTOCOLO DE LIMPIEZA RNDC - GRUPO 1 ===")

    # 1. Carga del conjunto de datos
    try:
        df = pd.read_csv(ruta_archivo, sep=',', quotechar='"', low_memory=False)
        print(f"Datos originales cargados: {df.shape[0]} registros y {df.shape[1]} columnas/características. \n")
        df.columns = df.columns.str.lower()
        print(f"\t Columnas del DF \n \n {df.columns.tolist()} \n")

        # === CAMBIO 1: ELIMINACIÓN DE NULOS AHORA ES TRANSPARENTE ===
        columnas_a_limpiar = [col for col in ['unid_medida', 'descargue'] if col in df.columns]
        if columnas_a_limpiar:
            print("--- Reporte de nulos en columnas críticas (antes de filtrar) ---")
            for col in columnas_a_limpiar:
                n_nulos = df[col].isna().sum()
                pct = (n_nulos / len(df)) * 100 if len(df) > 0 else 0
                print(f"  '{col}': {n_nulos} nulos ({pct:.2f}% del total)")

            filas_antes = df.shape[0]
            df = df.dropna(subset=columnas_a_limpiar)
            filas_eliminadas = filas_antes - df.shape[0]
            pct_eliminado = (filas_eliminadas / filas_antes) * 100 if filas_antes > 0 else 0
            print(f"✓ Se eliminaron {filas_eliminadas} registros ({pct_eliminado:.2f}%) por nulos en {columnas_a_limpiar}.")
            print(f"  Quedan {df.shape[0]} registros tras este filtro.\n")

    except Exception as e:
        return f"Error al cargar el archivo: {e}"

    # 2. Corrección Temporal
    if 'fechasalidacargue' in df.columns and 'hora_salida_cargue' in df.columns:
        fecha_real = pd.to_datetime(df['fechasalidacargue'], errors='coerce').dt.date
        hora_real = pd.to_datetime(df['hora_salida_cargue'], errors='coerce').dt.time
        df['FECHA_HORA_SALIDA_CORREGIDA'] = pd.to_datetime(fecha_real.astype(str) + ' ' + hora_real.astype(str), errors='coerce')
        print("✓ Corrección Temporal completada (Mitigación del desfase de 1899).")

    # 3. Normalización Financiera (Incluyendo Min-Max silencioso)
    if 'valor_pactado' in df.columns:
        df['valor_pactado'] = pd.to_numeric(df['valor_pactado'].astype(str).str.replace(r'[^\d.]', '', regex=True), errors='coerce')
        v_min = df['valor_pactado'].min()
        v_max = df['valor_pactado'].max()
        df['valor_pactado_norm'] = (df['valor_pactado'] - v_min) / (v_max - v_min) if v_max > v_min else 0.0
    print("✓ Normalización Financiera completada.\n")

    # 3.5. Normalización de Masas a Kilogramos (CRUCE CON DENSIDAD DE PRODUCTOS)
    print("Normalizando unidades de medida de carga a Kilogramos (basado en densidad del producto)...")
    if 'cantidad' in df.columns and 'unid_medida' in df.columns and 'producto' in df.columns:
        df['cantidad'] = pd.to_numeric(df['cantidad'], errors='coerce').fillna(0)
        df['unid_medida'] = df['unid_medida'].astype(str).str.upper().str.strip()
        mascara_galones = df['unid_medida'] == 'GALONES'

        if mascara_galones.sum() > 0:
            # 1. Definir función de mapeo de densidades (kg por galón) calibrada con NLP
            def estimar_densidad(nombre_producto):
                nombre = str(nombre_producto).lower()

                # 1. Combustibles y Petróleo (Tus keywords: combustibles, combustible, petróleo)
                if any(x in nombre for x in ['combustible', 'petróleo', 'petroleo', 'gasolina', 'acpm']):
                    return 3.15

                # 2. Aceites y Grasas (Tus keywords: aceites, aceite, grasas)
                elif any(x in nombre for x in ['aceite', 'grasa']):
                    return 3.40

                # 3. Lácteos (Tus keywords: leche, lácteos)
                elif any(x in nombre for x in ['leche', 'lácteo', 'lacteo']):
                    return 3.90

                # 4. Químicos y Abonos (Tus keywords: químicas, químicos, quimicos, abonos)
                # (Asumimos una densidad ligeramente mayor al agua para soluciones químicas industriales)
                elif any(x in nombre for x in ['química', 'quimica', 'químico', 'quimico', 'abono']):
                    return 4.10

                # 5. Bebidas, Agua y Alcoholes (Tus keywords: agua, bebidas, vinagre, alcohólicos, cerveza, gasificada)
                elif any(x in nombre for x in ['agua', 'bebida', 'vinagre', 'alcohólico', 'cerveza', 'gasificada']):
                    return 3.785

                # Por defecto: Líquidos generales
                else:
                    return 3.785

            # 2. Aplicar la función solo a los registros que están en galones
            df.loc[mascara_galones, 'densidad_estimada'] = df.loc[mascara_galones, 'producto'].apply(estimar_densidad)

            # 3. Realizar la conversión matemática: Galones * Densidad = Kilogramos
            df.loc[mascara_galones, 'cantidad'] = df.loc[mascara_galones, 'cantidad'] * df.loc[mascara_galones, 'densidad_estimada']
            df.loc[mascara_galones, 'unid_medida'] = 'KILOGRAMOS'

            # 4. Generar el CSV de auditoría para el equipo de investigación
            # Aisla los productos únicos que estaban en galones y su densidad asignada
            df_auditoria = df.loc[mascara_galones, ['producto', 'densidad_estimada']].drop_duplicates().sort_values('producto')
            df_auditoria.to_csv('Auditoria_Densidades_Galones.csv', index=False)

            # 5. Limpiar la columna temporal para no ensuciar el dataset final de Machine Learning
            df = df.drop(columns=['densidad_estimada'])

            print(f"✓ Se convirtieron {mascara_galones.sum()} registros de Galones a Kg usando densidades específicas.")
            print(f"✓ Se generó el archivo 'Auditoria_Densidades_Galones.csv' con {len(df_auditoria)} productos únicos para revisión.\n")
        else:
            print("✓ No se encontraron registros en Galones para convertir.\n")

        df['unid_medida'] = df['unid_medida'].replace('NAN', 'KILOGRAMOS')
    # 3.6. CÁLCULO DE DISTANCIA ESTIMADA (HAVERSINE)
    if 'cargue' in df.columns and 'descargue' in df.columns:
        # Diccionario de coordenadas actualizado con formato "CIUDAD DEPARTAMENTO" del RNDC
        coordenadas = {
            # Nodos de tu estudio (Formato RNDC)
            'CARTAGENA BOLIVAR': (10.3997, -75.5144),
            'LA DORADA CALDAS': (5.4528, -74.6719),
            'CHIRIGUANA CESAR': (9.3608, -73.5999),
            'CHIRIGUANÁ CESAR': (9.3608, -73.5999),
            'PUERTO SALGAR CUNDINAMARCA': (5.4630, -74.6548),
            'RINCON HONDO CHIRIGUANA CESAR': (9.3608, -73.5999),
            'BAYUNCA CARTAGENA BOLIVAR': (10.5500, -75.4333),

            # Top Capitales y Nodos Logísticos (Formato RNDC)
            'BOGOTA BOGOTA D. C.': (4.6097, -74.0817),
            'MEDELLIN ANTIOQUIA': (6.2442, -75.5812),
            'BARRANQUILLA ATLANTICO': (10.9685, -74.7813),
            'BUENAVENTURA VALLE DEL CAUCA': (3.8801, -77.0311),
            'CALI VALLE DEL CAUCA': (3.4516, -76.5319),
            'YUMBO VALLE DEL CAUCA': (3.5833, -76.4953),
            'FUNZA CUNDINAMARCA': (4.7167, -74.2114),
            'BUCARAMANGA SANTANDER': (7.1193, -73.1227),
            'PEREIRA RISARALDA': (4.8087, -75.6906),
            'TOCANCIPA CUNDINAMARCA': (4.9650, -73.9140),
            'SANTA MARTA MAGDALENA': (11.2408, -74.1990),
            'MANIZALES CALDAS': (5.0689, -75.5174),
            'CUCUTA NORTE DE SANTANDER': (7.8939, -72.5078),
            'COTA CUNDINAMARCA': (4.8105, -74.0991),
            'PALMIRA VALLE DEL CAUCA': (3.5394, -76.3036),
            'IBAGUE TOLIMA': (4.4389, -75.2322),
            'ITAGUI ANTIOQUIA': (6.1732, -75.6030),
            'RIONEGRO ANTIOQUIA': (6.1551, -75.3737),
            'GIRON SANTANDER': (7.0682, -73.1698),
            'MOSQUERA CUNDINAMARCA': (4.7059, -74.2302),
            'DOSQUEBRADAS RISARALDA': (4.8398, -75.6722),
            'ENVIGADO ANTIOQUIA': (6.1759, -75.5917),
            'GUADALAJARA DE BUGA VALLE DEL CAUCA': (3.9000, -76.3000),
            'BARRANCABERMEJA SANTANDER': (7.0653, -73.8547),
            'NEIVA HUILA': (2.9273, -75.2819),
            'VILLAVICENCIO META': (4.1420, -73.6266),
            'MALAMBO ATLANTICO': (10.8583, -74.7774),

            # --- TOP 20 CIUDADES FALTANTES (Nuevas Coordenadas) ---
            'MADRID CUNDINAMARCA': (4.7325, -74.2644),
            'TENJO CUNDINAMARCA': (4.8719, -74.1453),
            'GIRARDOTA ANTIOQUIA': (6.3755, -75.4461),
            'MONTERIA CORDOBA': (8.7514, -75.8814),
            'PASTO NARINO': (1.2136, -77.2811),
            'LA ESTRELLA LA ESTRELLA ANTIOQUIA': (6.1578, -75.6431),
            'ARMENIA QUINDIO': (4.5339, -75.6811),
            'GALAPA ATLANTICO': (10.8994, -74.8814),
            'VALLEDUPAR CESAR': (10.4631, -73.2531),
            'YOPAL CASANARE': (5.3378, -72.3958),
            'SOGAMOSO BOYACA': (5.7144, -72.9339),
            'SOACHA CUNDINAMARCA': (4.5781, -74.2144),
            'FACATATIVA CUNDINAMARCA': (4.8136, -74.3536),
            'BELLO ANTIOQUIA': (6.3331, -75.5583),
            'CAJICA CUNDINAMARCA': (4.9181, -74.0289),
            'CARTAGO VALLE DEL CAUCA': (4.6989, -75.9142),
            'SABANETA ANTIOQUIA': (6.1517, -75.6153),
            'SONSON ANTIOQUIA': (5.7114, -75.3111),
            'TUNJA BOYACA': (5.5353, -73.3678),
            'POPAYAN CAUCA': (2.4411, -76.6061),

            # Versiones cortas por si alguna viene limpia
            'CARTAGENA': (10.3997, -75.5144),
            'BOGOTA': (4.6097, -74.0817)
        }
        cargue_limpio = df['cargue'].astype(str).str.upper().str.strip()
        descargue_limpio = df['descargue'].astype(str).str.upper().str.strip()

        # === CAMBIO 3: REPORTE DE COBERTURA DE COORDENADAS ===
        ciudades_usadas = pd.concat([cargue_limpio, descargue_limpio])
        en_diccionario = ciudades_usadas.isin(coordenadas.keys())

        conteo_con_coords = ciudades_usadas[en_diccionario].value_counts()
        conteo_sin_coords = ciudades_usadas[~en_diccionario].value_counts()

        print("--- Cobertura del diccionario de coordenadas ---")
        print(f"Ciudades CON coordenadas registradas ({conteo_con_coords.shape[0]} nombres distintos, "
              f"{en_diccionario.sum()} apariciones en cargue+descargue):")
        print(conteo_con_coords.to_string())

        print(f"\nCiudades SIN coordenadas registradas ({conteo_sin_coords.shape[0]} nombres distintos, "
              f"{(~en_diccionario).sum()} apariciones en cargue+descargue):")
        if conteo_sin_coords.empty:
            print("  (ninguna — diccionario completo para este dataset)")
        else:
            print(conteo_sin_coords.to_string())
            print("\n  → Agrega estos nombres (con sus coordenadas) al diccionario 'coordenadas' "
                  "y vuelve a correr el script para reducir el uso de la mediana de relleno.")
        print()

        df['lat_origen'] = cargue_limpio.map(lambda x: coordenadas.get(x, (np.nan, np.nan))[0])
        df['lon_origen'] = cargue_limpio.map(lambda x: coordenadas.get(x, (np.nan, np.nan))[1])
        df['lat_destino'] = descargue_limpio.map(lambda x: coordenadas.get(x, (np.nan, np.nan))[0])
        df['lon_destino'] = descargue_limpio.map(lambda x: coordenadas.get(x, (np.nan, np.nan))[1])

        df['distancia_estimada_km'] = calcular_haversine_vectorizado(
            df['lat_origen'], df['lon_origen'], df['lat_destino'], df['lon_destino']
        )
        n_rellenados = df['distancia_estimada_km'].isna().sum()
        df['distancia_estimada_km'] = df['distancia_estimada_km'].fillna(df['distancia_estimada_km'].median())
        print(f"✓ {n_rellenados} registros sin coordenadas fueron rellenados con la mediana de distancia.\n")

    # 4. Atributo Protegido (A)
    if 'codigo_descargue' in df.columns:
        df['divipola_raiz'] = df['codigo_descargue'].astype(str).str.split('.').str[0].str.zfill(8).str[:5]
        print("\t Zonas de descargue a considerar en base a su código de descargue \n")
        print(f"La Dorada (17380) = {df['descargue'].loc[df['divipola_raiz'] == '17380'].unique()}")
        print(f"Chiriguaná (20178) = {df['descargue'].loc[df['divipola_raiz'] == '20178'].unique()}")
        print(f"Puerto Salgar (25572) = {df['descargue'].loc[df['divipola_raiz'] == '25572'].unique()}")
        print(f"Cartagena (13001) = {df['descargue'].loc[df['divipola_raiz'] =='13001'].unique()}\n")

        nodos_multimodales = ['17380', '20178', '25572', '13001']
        df['a_intermodal'] = np.where(df["codigo_descargue"].isna(), np.nan,
                                      np.where(df['divipola_raiz'].isin(nodos_multimodales), 0, 1))
        print("✓ Atributo Protegido (A) configurado por segmentación geográfica.")

    # 5. Variable Objetivo (Y)
    if 'horas_espera_descargue' in df.columns:
        df['horas_espera_descargue'] = pd.to_numeric(df['horas_espera_descargue'], errors='coerce')
        tau = df['horas_espera_descargue'].quantile(0.75)
        df['y_riesgo'] = np.where(df['horas_espera_descargue'].isna(), np.nan,
                                  (df['horas_espera_descargue'] > tau).astype(float))
        print(f"✓ Variable Objetivo (Y) configurada. Umbral crítico (Tau 75%): {tau:.2f} horas.\n")

    # 6. Integridad de Grupos e Impresión de Reporte
    variables_criticas = ['a_intermodal', 'y_riesgo', 'horas_espera_descargue']
    print("Se analizarán las VARIABLES CRÍTICAS (A, Y y horas de espera en descargue)\n")
    print("Valores nulos en cada variable crítica:")
    print(f"Horas espera descargue: {df['horas_espera_descargue'].isna().sum()}")
    print(f"A intermodal: {df['a_intermodal'].isna().sum()}")
    print(f"Y riesgo: {df['y_riesgo'].isna().sum()}\n")

    print("Se puede ver que las variables: 'codigo_descargue' y 'horas_esperas_descargue' son OBLIGATORIAS en la base de datos, y no hay ningún valor NULO.\n")

    print("Análisis de las Horas de espera:")
    print(f"% de registros con espera = 0: \t {(df['horas_espera_descargue'] == 0).mean() * 100:.2f}%\n")

    print("Horas de espera = 0 separada por A intermodal \n A=0: Periferia/Intermodal (Protegido) \n A=1: Central/Carretero (Favorecido)")
    serie_ceros = df.groupby('a_intermodal')['horas_espera_descargue'].apply(lambda x: (x == 0).mean() * 100)
    print("a_intermodal")
    print(f"0.0    {serie_ceros.get(0, 0):.6f}")
    print(f"1.0    {serie_ceros.get(1, 0):.6f}")
    print("Name: horas_espera_descargue, dtype: float64\n")

    diferencia_porcentual = serie_ceros.get(0, 0) - serie_ceros.get(1, 0)
    print(f"Hay aproximadamente {diferencia_porcentual:.1f}% más reportes de 0 en el A=0 que en A=1")
    print("(No se sabe si esto es por la zona, o por la empresa)\n")

    df_limpio = df.dropna(subset=[col for col in variables_criticas if col in df.columns])

    print("=== REPORTE EDA INICIAL (GRUPO 1) ===")
    print(f"Total de registros viables tras limpieza: {df_limpio.shape[0]}\n")

    print("Distribución del Atributo Protegido (A):")
    dist_A = df_limpio['a_intermodal'].value_counts(normalize=True) * 100
    print(f"Rutas Centrales Tradicionales (A=1): {dist_A.get(1, 0):.2f}%")
    print(f"Nodos Intermodales/Periferia (A=0): {dist_A.get(0, 0):.2f}%\n")

    print("Distribución de la Variable Objetivo (Y):")
    dist_Y = df_limpio['y_riesgo'].value_counts(normalize=True) * 100
    print(f"Operación Estándar (Y=0): {dist_Y.get(0, 0):.2f}%")
    print(f"Ineficiencia Crítica (Y=1): {dist_Y.get(1, 0):.2f}%\n")

    # Exportación
    df_limpio.to_csv('RNDC_Grupo1_Limpio_S1.csv', index=False)
    print("Archivo 'RNDC_Grupo1_Limpio_S1.csv' exportado exitosamente para la fase de modelamiento.")

    return df_limpio

# Ejecución
df_final_g1 = preprocesar_rndc_grupo1("Tiempos_Logísticos_de_cada_viaje_de_vehículos_de_carga_20260615.csv")
# Out:
# === INICIANDO PROTOCOLO DE LIMPIEZA RNDC - GRUPO 1 ===
# Datos originales cargados: 836013 registros y 26 columnas/características.
#
# 	 Columnas del DF
#
#  ['año/mes', 'naturaleza', 'cod_producto', 'producto', 'cantidad', 'unid_medida', 'fechasalidacargue', 'hora_salida_cargue', 'fechallegadadescargue', 'hora_llegada_descargue', 'codigo_cargue', 'cargue', 'codigo_descargue', 'descargue', 'horas_viaje', 'horas_espera_cargue', 'horas_cargue', 'horas_espera_descargue', 'horas_descargue', 'valor_pactado', 'valor_pagado', 'cantidad_remesas_viaje', 'empresa_transporte', 'placa', 'configuracion', 'conductor']
#
# --- Reporte de nulos en columnas críticas (antes de filtrar) ---
#   'unid_medida': 1662 nulos (0.20% del total)
#   'descargue': 25 nulos (0.00% del total)
# ✓ Se eliminaron 1687 registros (0.20%) por nulos en ['unid_medida', 'descargue'].
#   Quedan 834326 registros tras este filtro.
#
# ✓ Corrección Temporal completada (Mitigación del desfase de 1899).
# ✓ Normalización Financiera completada.
#
# Normalizando unidades de medida de carga a Kilogramos (basado en densidad del producto)...
# ✓ Se convirtieron 32971 registros de Galones a Kg usando densidades específicas.
# TAPARTO ANDES ANTIOQUIA                                           1
# CORCEGA LA UNION VALLE DEL CAUCA                                  1
# ALTAQUER BARBACOAS NARINO                                         1
# MORICHAL YOPAL CASANARE                                           1
# AGUAS CLARAS OCANA NORTE DE SANTANDER                             1
# SANTA ROSA PLANETA RICA CORDOBA                                   1
# HACARI NORTE DE SANTANDER                                         1
# GUALMATAN PASTO NARINO                                            1
# NOROSI RIO VIEJO BOLIVAR                                          1
# MADRIGAL POLICARPA NARINO                                         1
# SALOA CHIMICHAGUA CESAR                                           1
# LOMA DEL BALSAMO ALGARROBO MAGDALENA                              1
# SATIVASUR BOYACA                                                  1
# EL CARMELO CAJIBIO CAUCA                                          1
# GUAICARAMO PARATEBUENO CUNDINAMARCA                               1
# ALGARROBO EL BANCO MAGDALENA                                      1
# HUISITO EL TAMBO CAUCA                                            1
# LA SOMBRA LA MACARENA META                                        1
# VALLEJUELO ZARZAL VALLE DEL CAUCA                                 1
# CHIQUIZA BOYACA                                                   1
# RONDON BOYACA                                                     1
# BARRANCON TIERRALTA CORDOBA                                       1
# PLAYA ROJA BELEN DE BAJIRA CHOCO                                  1
# TOMARRAZON RIOHACHA LA GUAJIRA                                    1
# MICO AHUMADO MORALES BOLIVAR                                      1
# DOS QUEBRADAS TRUJILLO VALLE DEL CAUCA                            1
# PALOMAR ZONA BANANERA MAGDALENA                                   1
# LA PINUELA COCORNA ANTIOQUIA                                      1
# VERSALLES SANTA BARBARA ANTIOQUIA                                 1
# SAN CIPRIANO BUENAVENTURA VALLE DEL CAUCA                         1
# ZETAQUIRA BOYACA                                                  1
# PALMIRA TIERRALTA CORDOBA                                         1
# COCORA SALENTO QUINDIO                                            1
# SAN LUIS SUCRE SUCRE                                              1
# SAMARIA FILADELFIA CALDAS                                         1
# CALDAS VIEJO ALVARADO TOLIMA                                      1
# EL GUAMO MOMPOS BOLIVAR                                           1
#
#   → Agrega estos nombres (con sus coordenadas) al diccionario 'coordenadas' y vuelve a correr el script para reducir el uso de la mediana de relleno.
#
# ✓ 373987 registros sin coordenadas fueron rellenados con la mediana de distancia.
#
# 	 Zonas de descargue a considerar en base a su código de descargue
#
# La Dorada (17380) = ['LA DORADA CALDAS' 'GUARINOCITO LA DORADA CALDAS']
# Chiriguaná (20178) = ['RINCON HONDO CHIRIGUANA CESAR' 'CHIRIGUANA CESAR'
#  'EL CRUCE CHIRIGUANA CESAR' 'POPONTE CHIRIGUANA CESAR']
# Puerto Salgar (25572) = ['PUERTO SALGAR CUNDINAMARCA']
# Cartagena (13001) = ['CARTAGENA BOLIVAR' 'BAYUNCA CARTAGENA BOLIVAR' 'BARU CARTAGENA BOLIVAR'
#  'PUEBLO NUEVO CARTAGENA BOLIVAR' 'PASACABALLOS CARTAGENA BOLIVAR'
#  'LA BOQUILLA CARTAGENA BOLIVAR' 'ARROYO GRANDE CARTAGENA BOLIVAR'
#  'ARROYO DE PIEDRA CARTAGENA BOLIVAR' 'PUNTA CANOA CARTAGENA BOLIVAR'
#  'PUERTO REY CARTAGENA BOLIVAR' 'ARARCA CARTAGENA BOLIVAR']
#
# ✓ Atributo Protegido (A) configurado por segmentación geográfica.
# ✓ Variable Objetivo (Y) configurada. Umbral crítico (Tau 75%): 0.62 horas.
#
# Se analizarán las VARIABLES CRÍTICAS (A, Y y horas de espera en descargue)
#
# Valores nulos en cada variable crítica:
# Horas espera descargue: 0
# A intermodal: 0
# Y riesgo: 0
#
# Se puede ver que las variables: 'codigo_descargue' y 'horas_esperas_descargue' son OBLIGATORIAS en la base de datos, y no hay ningún valor NULO.
#
# Análisis de las Horas de espera:
# % de registros con espera = 0: 	 50.02%
#
# Horas de espera = 0 separada por A intermodal
#  A=0: Periferia/Intermodal (Protegido)
#  A=1: Central/Carretero (Favorecido)
# a_intermodal
# 0.0    53.660512
# 1.0    49.890704
# Name: horas_espera_descargue, dtype: float64
#
# Hay aproximadamente 3.8% más reportes de 0 en el A=0 que en A=1
# (No se sabe si esto es por la zona, o por la empresa)
#
# === REPORTE EDA INICIAL (GRUPO 1) ===
# Total de registros viables tras limpieza: 834326
#
# Distribución del Atributo Protegido (A):
# Rutas Centrales Tradicionales (A=1): 96.45%
# Nodos Intermodales/Periferia (A=0): 3.55%
#
# Distribución de la Variable Objetivo (Y):
# Operación Estándar (Y=0): 75.02%
# Ineficiencia Crítica (Y=1): 24.98%
#
# Archivo 'RNDC_Grupo1_Limpio_S1.csv' exportado exitosamente para la fase de modelamiento.

# %%
import pandas as pd
DF = pd.read_csv('/content/RNDC_Grupo1_Limpio_S1.csv')

# %%
print(DF.columns)
# Out:
# Index(['año/mes', 'naturaleza', 'cod_producto', 'producto', 'cantidad',
#        'unid_medida', 'fechasalidacargue', 'hora_salida_cargue',
#        'fechallegadadescargue', 'hora_llegada_descargue', 'codigo_cargue',
#        'cargue', 'codigo_descargue', 'descargue', 'horas_viaje',
#        'horas_espera_cargue', 'horas_cargue', 'horas_espera_descargue',
#        'horas_descargue', 'valor_pactado', 'valor_pagado',
#        'cantidad_remesas_viaje', 'empresa_transporte', 'placa',
#        'configuracion', 'conductor', 'FECHA_HORA_SALIDA_CORREGIDA',
#        'valor_pactado_norm', 'lat_origen', 'lon_origen', 'lat_destino',
#        'lon_destino', 'distancia_estimada_km', 'divipola_raiz', 'a_intermodal',
#        'y_riesgo'],
#       dtype='object')

# %% [markdown]
# # semana 2

# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score

# Silenciamos advertencias menores para mantener la consola limpia
warnings.filterwarnings('ignore')

def ejecutar_auditoria_semana2(ruta_csv):
    print("==========================================================")
    print("SISTEMAS NEURODIFUSOS - AUDITORÍA DE SESGO TERRITORIAL (S2)")
    print("==========================================================\n")

    # 1. Carga de los datos platino (Output de la Semana 1)
    try:
        df = pd.read_csv(ruta_csv, low_memory=False)
        print(f"✓ Dataset limpio cargado exitosamente. Registros: {df.shape[0]}\n")
    except Exception as e:
        print(f"[ERROR CRÍTICO] No se pudo cargar el archivo: {e}")
        return

    print("--- 1. Preparando Motor de Machine Learning ---")

    # 2. Transformación Categórica
    # El Random Forest no lee texto, así que convertimos los nombres de ciudades a IDs numéricos
    df['cargue_encoded'] = df['cargue'].astype(str).astype('category').cat.codes
    df['descargue_encoded'] = df['descargue'].astype(str).astype('category').cat.codes

    # 3. Selección del Vector de Características (Features)
    # Usamos las variables maestras que enriquecimos en la Semana 1
    caracteristicas_modelo = [
        'cantidad',
        'valor_pactado_norm',
        'distancia_estimada_km',
        'cargue_encoded',
        'descargue_encoded'
    ]

    # Aseguramos que no haya ningún nulo rezagado que rompa el modelo
    df = df.dropna(subset=caracteristicas_modelo + ['y_riesgo', 'a_intermodal'])

    X = df[caracteristicas_modelo]
    y = df['y_riesgo']
    A = df['a_intermodal']

    # 4. División Estratificada (Train/Test Split)
    print("✓ Dividiendo datos (70% Entrenamiento / 30% Prueba)...")
    X_train, X_test, y_train, y_test, A_train, A_test = train_test_split(
        X, y, A, test_size=0.3, random_state=42, stratify=y
    )

    # 5. Entrenamiento del Modelo Predictivo
    print("✓ Entrenando algoritmo Random Forest (Esto tomará 1-2 minutos)...")
    # n_jobs=-1 exprime todo el procesador para entrenar más rápido
    modelo_base = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
    modelo_base.fit(X_train, y_train)

    # 6. Inferencia (Predicciones sobre el 30% de datos que el modelo nunca ha visto)
    print("✓ Ejecutando predicciones y motor de auditoría...\n")
    y_pred = modelo_base.predict(X_test)

    # =========================================================================
    # 7. EVALUACIÓN Y AUDITORÍA DE EQUIDAD (FAIRNESS ML)
    # =========================================================================

    # Accuracy Global (La métrica "trampa" que oculta el sesgo)
    accuracy_global = accuracy_score(y_test, y_pred)

    # Unimos resultados para separar por subpoblación
    df_auditoria = pd.DataFrame({
        'A_intermodal': A_test.values,
        'Y_real': y_test.values,
        'Y_pred': y_pred
    })

    # Segmentación
    grupo_protegido = df_auditoria[df_auditoria['A_intermodal'] == 0]    # Periferia / Intermodal
    grupo_favorecido = df_auditoria[df_auditoria['A_intermodal'] == 1]   # Centro / Carretero

    # --- Cálculos Matemáticos de Fairness ---

    # 1. Paridad Estadística (SPD) e Impacto Dispar (DI)
    prob_prot = grupo_protegido['Y_pred'].mean()
    prob_fav = grupo_favorecido['Y_pred'].mean()
    spd = prob_prot - prob_fav
    di = prob_prot / prob_fav if prob_fav > 0 else np.nan

    # 2. Igualdad de Oportunidades (EOD - Ceguera ante el riesgo real)
    def calcular_tpr(df_sub):
        # Verdaderos Positivos / (Verdaderos Positivos + Falsos Negativos)
        cm = confusion_matrix(df_sub['Y_real'], df_sub['Y_pred'], labels=[0, 1])
        tn, fp, fn, tp = cm.ravel()
        return tp / (tp + fn) if (tp + fn) > 0 else 0

    tpr_prot = calcular_tpr(grupo_protegido)
    tpr_fav = calcular_tpr(grupo_favorecido)
    eod = tpr_prot - tpr_fav

    # 3. Métricas de Rendimiento Desglosadas
    acc_prot = accuracy_score(grupo_protegido['Y_real'], grupo_protegido['Y_pred'])
    prec_prot = precision_score(grupo_protegido['Y_real'], grupo_protegido['Y_pred'], zero_division=0)
    rec_prot = recall_score(grupo_protegido['Y_real'], grupo_protegido['Y_pred'], zero_division=0)

    acc_fav = accuracy_score(grupo_favorecido['Y_real'], grupo_favorecido['Y_pred'])
    prec_fav = precision_score(grupo_favorecido['Y_real'], grupo_favorecido['Y_pred'], zero_division=0)
    rec_fav = recall_score(grupo_favorecido['Y_real'], grupo_favorecido['Y_pred'], zero_division=0)

    # --- IMPRESIÓN DEL REPORTE FINAL ---
    print("--- RENDIMIENTO GLOBAL DEL MODELO ---")
    print(f"Accuracy Global: {accuracy_global:.4f} (El modelo parece funcionar bien en general)\n")

    print("--- MOTOR DE AUDITORÍA MATEMÁTICA (SESGO TERRITORIAL) ---")
    print(f"Diferencia de Paridad Estadística (SPD):         {spd:.4f}")
    print(f"Impacto Dispar (DI):                             {di:.4f}")
    print(f"Diferencia de Igualdad de Oportunidades (EOD):   {eod:.4f}\n")

    print("=== TABLA DE ENMASCARAMIENTO POR SUBPOBLACIÓN ===")
    print(f"A=1 (Centro Carretero) -> Accuracy: {acc_fav:.4f} | Precisión: {prec_fav:.4f} | Recall: {rec_fav:.4f}")
    print(f"A=0 (Nodos Periferia)  -> Accuracy: {acc_prot:.4f} | Precisión: {prec_prot:.4f} | Recall: {rec_prot:.4f}")

    diferencia_recall = (rec_fav - rec_prot) * 100
    print(f"\n[ALERTA DE SESGO] El modelo es {diferencia_recall:.1f}% MÁS INCAPAZ de detectar ineficiencias en la Periferia que en el Centro.")
    print("==========================================================")

# --- EJECUCIÓN DEL SCRIPT ---
# Carga el archivo platino que acabamos de exportar en la Semana 1
ejecutar_auditoria_semana2('RNDC_Grupo1_Limpio_S1.csv')
# Out:
# ==========================================================
# SISTEMAS NEURODIFUSOS - AUDITORÍA DE SESGO TERRITORIAL (S2)
# ==========================================================
#
# ✓ Dataset limpio cargado exitosamente. Registros: 834326
#
# --- 1. Preparando Motor de Machine Learning ---
# ✓ Dividiendo datos (70% Entrenamiento / 30% Prueba)...
# ✓ Entrenando algoritmo Random Forest (Esto tomará 1-2 minutos)...
# ✓ Ejecutando predicciones y motor de auditoría...
#
# --- RENDIMIENTO GLOBAL DEL MODELO ---
# Accuracy Global: 0.8667 (El modelo parece funcionar bien en general)
#
# --- MOTOR DE AUDITORÍA MATEMÁTICA (SESGO TERRITORIAL) ---
# Diferencia de Paridad Estadística (SPD):         -0.0157
# Impacto Dispar (DI):                             0.9257
# Diferencia de Igualdad de Oportunidades (EOD):   -0.0419
#
# === TABLA DE ENMASCARAMIENTO POR SUBPOBLACIÓN ===
# A=1 (Centro Carretero) -> Accuracy: 0.8670 | Precisión: 0.7788 | Recall: 0.6550
# A=0 (Nodos Periferia)  -> Accuracy: 0.8576 | Precisión: 0.7309 | Recall: 0.6131
#
# [ALERTA DE SESGO] El modelo es 4.2% MÁS INCAPAZ de detectar ineficiencias en la Periferia que en el Centro.
# ==========================================================
